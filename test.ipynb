# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## S11one

# %%
S11one = pd.read_csv('./S11one.csv', header=None)
plt.imshow(S11one)
plt.colorbar()

# %%
plt.imshow(abs(S11one), norm='log')
plt.colorbar()

# %% [markdown]
# ## S22one

# %%
S22one = pd.read_csv('./S22one.csv', header=None)
plt.imshow(S22one)
plt.colorbar()

# %%
plt.imshow(abs(S22one), norm='log')
plt.colorbar()

# %% [markdown]
# ## C11one

# %%
C11one = pd.read_csv('./C11one.csv', header=None)
plt.imshow(C11one)
plt.colorbar()

# %%
plt.imshow(abs(C11one), norm='log')
plt.colorbar()

# %% [markdown]
# ## C11two

# %%
C11two = pd.read_csv('./C11two.csv', header=None)
plt.imshow(C11two)
plt.colorbar()

# %%
plt.imshow(abs(C11two), norm='log')
plt.colorbar()

# %% [markdown]
# ## C22one

# %%
C22one = pd.read_csv('./C22one.csv', header=None)
plt.imshow(C22one)
plt.colorbar()

# %%
plt.imshow(abs(C22one), norm='log')
plt.colorbar()

# %% [markdown]
# ## C22two

# %%
C22two = pd.read_csv('./C22two.csv', header=None)
plt.imshow(C22two)
plt.colorbar()

# %%
plt.imshow(abs(C22two), norm='log')
plt.colorbar()

# %% [markdown]
# ## C11three

# %%
C11three = pd.read_csv('./C11three.csv', header=None)
plt.imshow(C11three)
plt.colorbar()

# %%
plt.imshow(abs(C11three), norm='log')
plt.colorbar()

# %% [markdown]
# ## C22three

# %%
C22three = pd.read_csv('./C22three.csv', header=None)
plt.imshow(C22three)
plt.colorbar()

# %%
plt.imshow(abs(C22three), norm='log')
plt.colorbar()

# %% [markdown]
# ## C12three

# %%
C12three = pd.read_csv('./C12three.csv', header=None)
plt.imshow(C12three)
plt.colorbar()

# %%
plt.imshow(abs(C11three), norm='log')
plt.colorbar()
